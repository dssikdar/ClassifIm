# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Dropout
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

import matplotlib.pyplot as plt
# Out:
# 2024-06-09 21:47:12.407627: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(train_images, train_labels),  (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Combine train and test sets
all_images = np.concatenate((train_images, test_images), axis=0)
all_labels = np.concatenate((train_labels, test_labels), axis=0)

# Shuffle the combined dataset
indices = np.arange(len(all_images))
np.random.shuffle(indices)
all_images = all_images[indices]
all_labels = all_labels[indices]

# %%
# Calculate the number of samples for each split
num_total = len(all_images)
num_train = int(0.6 * num_total)
num_val = int(0.2 * num_total)
num_test = num_total - num_train - num_val

# Split the data
train_images = all_images[:num_train]
train_labels = all_labels[:num_train]
val_images = all_images[num_train:num_train + num_val]
val_labels = all_labels[num_train:num_train + num_val]
test_images = all_images[num_train + num_val:]
test_labels = all_labels[num_train + num_val:]

print("Training data shape:", train_images.shape)
print("Validation data shape:", val_images.shape)
print("Test data shape:", test_images.shape)
# Out:
# Training data shape: (36000, 32, 32, 3)
# Validation data shape: (12000, 32, 32, 3)
# Test data shape: (12000, 32, 32, 3)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])

    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
## Creating the Convolutional Neural Network model 
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='leaky_relu', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
#model.add(Dropout(0.15))
model.add(layers.Conv2D(64, (3, 3), activation='leaky_relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
#model.add(Dropout(0.15))

## Neural Network
model.add(layers.Flatten())
model.add(layers.Dense(56, activation='leaky_relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.2))
model.add(layers.Dense(10))

## Display model architecture
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  batch_normalization_3 (Batc  (None, 30, 30, 32)       128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 13, 13, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 56)                129080
#
#  batch_normalization_5 (Batc  (None, 56)               224
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 56)                0
#
#  dense_3 (Dense)             (None, 10)                570
#
# =================================================================
# Total params: 149,650
# Trainable params: 149,346
# Non-trainable params: 304
# _________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-5, verbose=1, mode='auto')

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=50, validation_data=(val_images, val_labels), callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 1125/1125 [==============================] - 29s 26ms/step - loss: 1.4222 - accuracy: 0.5012 - val_loss: 1.3971 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 2/50
# 1125/1125 [==============================] - 29s 26ms/step - loss: 1.0833 - accuracy: 0.6237 - val_loss: 1.1183 - val_accuracy: 0.6022 - lr: 0.0010
# Epoch 3/50
# 1125/1125 [==============================] - 30s 27ms/step - loss: 0.9679 - accuracy: 0.6644 - val_loss: 1.3089 - val_accuracy: 0.5702 - lr: 0.0010
# Epoch 4/50
# 1125/1125 [==============================] - 30s 27ms/step - loss: 0.8881 - accuracy: 0.6923 - val_loss: 1.0610 - val_accuracy: 0.6409 - lr: 0.0010
# Epoch 5/50
# 1125/1125 [==============================] - 31s 27ms/step - loss: 0.8354 - accuracy: 0.7100 - val_loss: 1.0596 - val_accuracy: 0.6337 - lr: 0.0010
# Epoch 6/50
# 1125/1125 [==============================] - 31s 27ms/step - loss: 0.7808 - accuracy: 0.7286 - val_loss: 0.9218 - val_accuracy: 0.6814 - lr: 0.0010
# Epoch 7/50
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.7375 - accuracy: 0.7446 - val_loss: 1.5730 - val_accuracy: 0.5215 - lr: 0.0010
# Epoch 8/50
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6967 - accuracy: 0.7577 - val_loss: 0.9592 - val_accuracy: 0.6770 - lr: 0.0010
# Epoch 9/50
# 1125/1125 [==============================] - 31s 27ms/step - loss: 0.6601 - accuracy: 0.7701 - val_loss: 1.0299 - val_accuracy: 0.6718 - lr: 0.0010
# Epoch 10/50
# 1125/1125 [==============================] - 31s 27ms/step - loss: 0.6259 - accuracy: 0.7835 - val_loss: 1.0918 - val_accuracy: 0.6437 - lr: 0.0010
# Epoch 11/50
# 1123/1125 [============================>.] - ETA: 0s - loss: 0.5992 - accuracy: 0.7894
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1125/1125 [==============================] - 30s 27ms/step - loss: 0.5989 - accuracy: 0.7895 - val_loss: 1.0090 - val_accuracy: 0.6724 - lr: 0.0010
# Epoch 12/50
# 1125/1125 [==============================] - 31s 27ms/step - loss: 0.4726 - accuracy: 0.8383 - val_loss: 0.8355 - val_accuracy: 0.7195 - lr: 1.0000e-04
# Epoch 13/50
# 1125/1125 [==============================] - 31s 28ms/step - loss: 0.4472 - accuracy: 0.8471 - val_loss: 0.8518 - val_accuracy: 0.7183 - lr: 1.0000e-04
# Epoch 14/50
# 1125/1125 [==============================] - 31s 28ms/step - loss: 0.4272 - accuracy: 0.8529 - val_loss: 0.8599 - val_accuracy: 0.7191 - lr: 1.0000e-04
# Epoch 15/50
# 1125/1125 [==============================] - 31s 28ms/step - loss: 0.4120 - accuracy: 0.8574 - val_loss: 0.8785 - val_accuracy: 0.7161 - lr: 1.0000e-04
# Epoch 16/50
# 1125/1125 [==============================] - 30s 27ms/step - loss: 0.4051 - accuracy: 0.8592 - val_loss: 0.8696 - val_accuracy: 0.7166 - lr: 1.0000e-04
# Epoch 17/50
# 1124/1125 [============================>.] - ETA: 0s - loss: 0.3956 - accuracy: 0.8640
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1125/1125 [==============================] - 35s 31ms/step - loss: 0.3958 - accuracy: 0.8639 - val_loss: 0.8764 - val_accuracy: 0.7220 - lr: 1.0000e-04
# Epoch 18/50
# 1125/1125 [==============================] - 32s 28ms/step - loss: 0.3758 - accuracy: 0.8719 - val_loss: 0.8708 - val_accuracy: 0.7219 - lr: 1.0000e-05
# Epoch 19/50
# 1125/1125 [==============================] - 33s 29ms/step - loss: 0.3758 - accuracy: 0.8703 - val_loss: 0.8719 - val_accuracy: 0.7220 - lr: 1.0000e-05
# Epoch 20/50
# 1125/1125 [==============================] - 33s 29ms/step - loss: 0.3720 - accuracy: 0.8728 - val_loss: 0.8737 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 21/50
# 1125/1125 [==============================] - 33s 29ms/step - loss: 0.3669 - accuracy: 0.8742 - val_loss: 0.8753 - val_accuracy: 0.7213 - lr: 1.0000e-05
# Epoch 22/50
# 1124/1125 [============================>.] - ETA: 0s - loss: 0.3673 - accuracy: 0.8753
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-05.
# 1125/1125 [==============================] - 33s 29ms/step - loss: 0.3673 - accuracy: 0.8753 - val_loss: 0.8760 - val_accuracy: 0.7204 - lr: 1.0000e-05
# Epoch 23/50
# 1125/1125 [==============================] - 33s 30ms/step - loss: 0.3649 - accuracy: 0.8754 - val_loss: 0.8771 - val_accuracy: 0.7219 - lr: 1.0000e-05
# Epoch 24/50
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.3674 - accuracy: 0.8733 - val_loss: 0.8806 - val_accuracy: 0.7207 - lr: 1.0000e-05
# Epoch 25/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.3659 - accuracy: 0.8759 - val_loss: 0.8815 - val_accuracy: 0.7203 - lr: 1.0000e-05
# Epoch 26/50
# 1125/1125 [==============================] - 20s 18ms/step - loss: 0.3658 - accuracy: 0.8758 - val_loss: 0.8821 - val_accuracy: 0.7207 - lr: 1.0000e-05
# Epoch 27/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.3611 - accuracy: 0.8758 - val_loss: 0.8816 - val_accuracy: 0.7188 - lr: 1.0000e-05
# Epoch 28/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.3619 - accuracy: 0.8736 - val_loss: 0.8844 - val_accuracy: 0.7219 - lr: 1.0000e-05
# Epoch 29/50
# 1125/1125 [==============================] - 21s 19ms/step - loss: 0.3596 - accuracy: 0.8760 - val_loss: 0.8877 - val_accuracy: 0.7203 - lr: 1.0000e-05
# Epoch 30/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.3585 - accuracy: 0.8775 - val_loss: 0.8875 - val_accuracy: 0.7220 - lr: 1.0000e-05
# Epoch 31/50
# 1125/1125 [==============================] - 24s 21ms/step - loss: 0.3534 - accuracy: 0.8801 - val_loss: 0.8871 - val_accuracy: 0.7207 - lr: 1.0000e-05
# Epoch 32/50
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.3571 - accuracy: 0.8795 - val_loss: 0.8896 - val_accuracy: 0.7220 - lr: 1.0000e-05
# Epoch 33/50
# 1125/1125 [==============================] - 24s 22ms/step - loss: 0.3524 - accuracy: 0.8813 - val_loss: 0.8910 - val_accuracy: 0.7220 - lr: 1.0000e-05
# Epoch 34/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.3551 - accuracy: 0.8768 - val_loss: 0.8917 - val_accuracy: 0.7214 - lr: 1.0000e-05
# Epoch 35/50
# 1125/1125 [==============================] - 22s 19ms/step - loss: 0.3555 - accuracy: 0.8779 - val_loss: 0.8941 - val_accuracy: 0.7223 - lr: 1.0000e-05
# Epoch 36/50
#  206/1125 [====>.........................] - ETA: 16s - loss: 0.3660 - accuracy: 0.8791
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 history = model.fit(train_images, train_labels, epochs=50, validation_data=(val_images, val_labels), callbacks=[reduce_lr])
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)

datagen.fit(train_images)

# %%
history = model.fit(datagen.flow(train_images, train_labels, batch_size=64),
                    epochs=20, validation_data=(val_images, val_labels), 
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/20
#  95/563 [====>.........................] - ETA: 25s - loss: 2.0033 - accuracy: 0.0866
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 history = model.fit(datagen.flow(train_images, train_labels, batch_size=64),
#       2                     epochs=20, validation_data=(val_images, val_labels),
#       3                     callbacks=[reduce_lr])
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:506, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
# --> 506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#     509         inputs=args,
#     510         attrs=attrs,
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#     513 # Replace empty list with None
#     514 outputs = outputs or None
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:207, in _InterpolateFunctionError.__exit__(self, typ, exc, tb)
#     206 def __exit__(self, typ, exc, tb):
# --> 207   if not exc or not isinstance(exc, errors.OpError):
#     208     return False
#     209   message = compat.as_text(exc.message)
#
# KeyboardInterrupt:

# %%
# Plot training history
plt.figure(figsize=(12, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 # Plot accuracy
#       5 plt.subplot(1, 2, 1)
# ----> 6 plt.plot(history.history['accuracy'], label='Training Accuracy')
#       7 plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#       8 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %%
# Make predictions
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_labels.flatten()
# Out:
# 375/375 [==============================] - 2s 5ms/step

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)

# Calculate the accuracy score
test_accuracy = accuracy_score(test_labels, predicted_labels)
print(f"Accuracy Score: {test_accuracy:.3f}")

# Calculate the F1 Score
f1 = f1_score(true_labels, predicted_labels, average='weighted')
print(f"F1 Score: {f1:.3f}")
# Out:
# 375/375 [==============================] - 2s 6ms/step - loss: 0.8660 - accuracy: 0.7334
# Test accuracy: 0.7334166765213013
# Test loss: 0.8660443425178528
# Accuracy Score: 0.733
# F1 Score: 0.733

# %%
# Make predictions
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_labels.flatten()
# Out:
# 375/375 [==============================] - 2s 6ms/step

# %%
# Compute and display the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()
